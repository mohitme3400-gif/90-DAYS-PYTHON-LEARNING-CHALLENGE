# %%
num = [10, 5, 20, 8]

smallest = float('inf')
second = float('inf')

for i in num:
    if i < smallest:
        second = smallest
        smallest = i
    elif i < second and i != smallest:
        second = i

print('second smallest', second)
# Out:
# second smallest 8

# %%
num = [1, 2, 3, 4]

if nums == sorted(nums):
    print('Sorted')
else:
    print('Not sorted')
# Out:
# Not sorted

# %%
num = [12, 41, 13, 45]
count = 0

for i in num:
    count += 1

print(a)
# Out:
# 4
