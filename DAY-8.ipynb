# %%
a = input('enter a word')

if a in 'aeiouAEIOU':
    print("Vowel") 
else:
    print('Consonant')
# Out:
# enter a word E
# Vowel

# %%
a = 'Eduction'
print(len(a))
# Out:
# 8

# %%
x = 'Python'
count = 0

for i in x :
    if i in 'aeiouAEIOU':
        count += 1
print(count)
# Out:
# 1

# %%
y = 'Mohit'

y[::-1]
# Out:
# 'tihoM'

# %%
B = input('enter a word')

if B == B [::-1]:
    print('Palindrome')
else:
    print('Not a Palindrome')
# Out:
# enter a word madam
# Palindrome
