# %%
a = 5
b = 15

c = a
a = b
b = c


print(a )
# Out:
# 15

# %%
year = int(input('enter a year :'))
if year % 400 == 0:
    print('Leap Year')
elif year % 100 == 0:
    print('Not a leap year')
elif year % 4 == 0:
    print('leap year')
else:
    print('not a leap year')
# Out:
# enter a year : 2024
# leap year

# %%
a = [1, 2, 3, 4, 5]
a.reverse()
a
# Out:
# [5, 4, 3, 2, 1]

# %%
a[::-1]
# Out:
# [1, 2, 3, 4, 5]

# %%
num = input('enter a number :')
print(len(num))
# Out:
# enter a number : .2152842152854
# 14

# %%
num = int(input('enter a number'))
a = 1
for i in range (1, num + 1):
    a = a*i
print(a)
# Out:
# enter a number 12
# 479001600
