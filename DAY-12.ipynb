# %%
import pandas as pd

# %%
data =pd.read_csv('train.csv')

# %%
data = {
    "Name": ["Mohit", "Rahul", "Aman"],
    "Age": [20, 22, 19],
    "City": ["Delhi", "Mumbai", "Jaipur"]
}

df = pd.DataFrame(data)

print(df)
# Out:
#     Name  Age    City
# 0  Mohit   20   Delhi
# 1  Rahul   22  Mumbai
# 2   Aman   19  Jaipur

# %%
data['Name']
# Out:
# ['Mohit', 'Rahul', 'Aman']

# %%
data['Age']
# Out:
# [20, 22, 19]
