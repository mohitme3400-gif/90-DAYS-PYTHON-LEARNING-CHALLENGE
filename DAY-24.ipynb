# %%
num = int(input('Enter a number'))
fact = 1

for i in range(1, 11):
    fact = fact*i

print(fact)
# Out:
# Enter a number 45
# 3628800

# %%
num = int(input('Enter a Number'))
count = 0

for i in range(1, (num+1)):
    if num % i == 0:
        count += 1

if count == 2:
        print('Prime number')
else:
        print( 'Not a prime number')
# Out:
# Enter a Number 45
# Not a prime number

# %%
sentence = 'I am larning python'
words = sentence.split()
count = 0

for word in words:
    if word[0].lower() in 'aeiou':
        count += 1
print(count)
# Out:
# 2
